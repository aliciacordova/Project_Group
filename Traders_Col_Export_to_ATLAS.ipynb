# %% [markdown]
# # Traders Database Consolidation and Export to MongoDB Atlas
#
# This notebook creates a consolidated MongoDB collection and exports it to our main MongoDB database store in MongoDB Atlas, 'crypto_punks_mdb':
#
# * traders_col
#
# ### To manage the MongoDB Atlas database through MongoDB Compass, establish a connection using the following as the connection URI:
#
# mongodb+srv://[user]:[password]@cluster0.wddnt.mongodb.net/[my_database]?retryWrites=true&w=majority"
#
# Replace [user] and [password] for the cluster's user and password, and replace [my_database] with crypto_punks_mdb.

# %%
# Import main dependencies
import pandas as pd
import numpy as np
import json

# Import image handling libraries
from PIL import Image

# Import MongoDB libraries for database management 
import pymongo
from pymongo import MongoClient

import time

# %% [markdown]
# # Create a Connection to MongoDB Atlas

# %%
# Make a connection to Mongo with MongoClient (use this URI to establish 
# connection with MongoDB Atlas)

# 1. Get user and password for Atlas cluster connection
from config import user, password

# 2. Establish which database in the Atlas cluster to connect to
my_database = "crypto_punks_mdb"

atlas_path = "mongodb+srv://"+user+":"+password+"@cluster0.wddnt.mongodb.net/"+my_database+"?retryWrites=true&w=majority"

# %%
# 3. Establish the connection as a pyMongo client using the
# path to the cluster provided by your Atlas account
atlas_client = pymongo.MongoClient(atlas_path)

# 4. Verify connection was established
print(atlas_client.test)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.wddnt.mongodb.net:27017', 'cluster0-shard-00-00.wddnt.mongodb.net:27017', 'cluster0-shard-00-01.wddnt.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-8x2to2-shard-0', tls=True), 'test')

# %%
# Create an object to point to the database
crypto_punks_mdb = atlas_client[my_database]

# %% [markdown]
# ## Export the traders_col to Mongo DB Atlas

# %%
# Read the traders.csv as a dataframe
traders_df = pd.read_csv("Data/traders.csv")
traders_df
# Out:
#          index trader_id       txn_type  punk_id     eth                 date  \
# 0         4950       007            Bid      521    0.10  2019-12-17 00:00:00
# 1         4949       007  Bid Withdrawn      521    0.10  2020-01-02 00:00:00
# 2       126547       007      Purchased     7750    0.70  2020-04-07 00:00:00
# 3       126545       007           Sold     7750    0.85  2020-04-08 00:00:00
# 4       160412  0age.eth            Bid     9626   12.34  2021-06-09 00:00:00
# ...        ...       ...            ...      ...     ...                  ...
# 132521  118768   🤹🏻‍♂.e…            Bid     7334   89.00  2021-09-07 00:00:00
# 132522  118764   🤹🏻‍♂.e…  Bid Withdrawn     7334  111.00  2021-09-08 00:00:00
# 132523  118765   🤹🏻‍♂.e…            Bid     7334  111.00  2021-09-08 00:00:00
# 132524   51870    🦊🦄👩‍?…      Purchased     3520   32.00  2021-07-31 00:00:00
# 132525   51869    🦊🦄👩‍?…       Transfer     3520    0.00  2021-08-23 00:00:00
#
#                   timestamp     source
# 0       2019-12-17 00:00:00  larvalabs
# 1       2020-01-02 00:00:00  larvalabs
# 2       2020-04-07 00:00:00  larvalabs
# 3       2020-04-08 00:00:00  larvalabs
# 4       2021-06-09 00:00:00  larvalabs
# ...                     ...        ...
# 132521  2021-09-07 00:00:00  larvalabs
# 132522  2021-09-08 00:00:00  larvalabs
# 132523  2021-09-08 00:00:00  larvalabs
# 132524  2021-07-31 00:00:00  larvalabs
# 132525  2021-08-23 00:00:00  larvalabs
#
# [132526 rows x 8 columns]

# %%
# Inspect data types for compatibility with MongoDB
traders_df.dtypes
# Out:
# index          int64
# trader_id     object
# txn_type      object
# punk_id        int64
# eth          float64
# date          object
# timestamp     object
# source        object
# dtype: object

# %%
# Change incompatible data types
traders_df = traders_df.astype(str)
traders_df.dtypes
# Out:
# index        object
# trader_id    object
# txn_type     object
# punk_id      object
# eth          object
# date         object
# timestamp    object
# source       object
# dtype: object

# %%
# Reinspect the dataframe
traders_df
# Out:
#          index trader_id       txn_type punk_id                 eth  \
# 0         4950       007            Bid     521                 0.1
# 1         4949       007  Bid Withdrawn     521                 0.1
# 2       126547       007      Purchased    7750  0.7000000000000001
# 3       126545       007           Sold    7750                0.85
# 4       160412  0age.eth            Bid    9626               12.34
# ...        ...       ...            ...     ...                 ...
# 132521  118768   🤹🏻‍♂.e…            Bid    7334                89.0
# 132522  118764   🤹🏻‍♂.e…  Bid Withdrawn    7334               111.0
# 132523  118765   🤹🏻‍♂.e…            Bid    7334               111.0
# 132524   51870    🦊🦄👩‍?…      Purchased    3520                32.0
# 132525   51869    🦊🦄👩‍?…       Transfer    3520                 0.0
#
#                        date            timestamp     source
# 0       2019-12-17 00:00:00  2019-12-17 00:00:00  larvalabs
# 1       2020-01-02 00:00:00  2020-01-02 00:00:00  larvalabs
# 2       2020-04-07 00:00:00  2020-04-07 00:00:00  larvalabs
# 3       2020-04-08 00:00:00  2020-04-08 00:00:00  larvalabs
# 4       2021-06-09 00:00:00  2021-06-09 00:00:00  larvalabs
# ...                     ...                  ...        ...
# 132521  2021-09-07 00:00:00  2021-09-07 00:00:00  larvalabs
# 132522  2021-09-08 00:00:00  2021-09-08 00:00:00  larvalabs
# 132523  2021-09-08 00:00:00  2021-09-08 00:00:00  larvalabs
# 132524  2021-07-31 00:00:00  2021-07-31 00:00:00  larvalabs
# 132525  2021-08-23 00:00:00  2021-08-23 00:00:00  larvalabs
#
# [132526 rows x 8 columns]

# %%
# Create an empty list of dictionaries
traders_list=[]

# %%
# Loop through the dataframe to populate the list while also adding the bitmap image
for row in range(len(traders_df)):

    # Add the trader data to the traders_list as
    # a dictionary
    traders_list.append({"txn_index": traders_df.at[row,"index"],
                         "trader_id": traders_df.at[row,"trader_id"],
                         "txn_type": traders_df.at[row,"txn_type"],
                         "punk_id": traders_df.at[row,"punk_id"],
                         "eth": traders_df.at[row,"eth"],
                         "date": traders_df.at[row,"date"],
                         "timestamp": traders_df.at[row,"timestamp"],
                         "source": traders_df.at[row,"source"]
                        })

# %%
# Inspect the first record of the list
traders_list[0]
# Out:
# {'txn_index': '4950',
#  'trader_id': '007',
#  'txn_type': 'Bid',
#  'punk_id': '521',
#  'eth': '0.1',
#  'date': '2019-12-17 00:00:00',
#  'timestamp': '2019-12-17 00:00:00',
#  'source': 'larvalabs'}

# %%
# Try adding the traders as a collection to the database in a single read
crypto_punks_mdb.traders_col.insert_many(traders_list)
# Out:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# ~/miniforge3/lib/python3.9/site-packages/pymongo/pool.py in send_message(self, message, max_doc_size)
#     749         try:
# --> 750             self.sock.sendall(message)
#     751         except BaseException as error:
#
# ~/miniforge3/lib/python3.9/ssl.py in sendall(self, data, flags)
#    1203                 while count < amount:
# -> 1204                     v = self.send(byte_view[count:])
#    1205                     count += v
#
# ~/miniforge3/lib/python3.9/ssl.py in send(self, data, flags)
#    1172                     self.__class__)
# -> 1173             return self._sslobj.write(data)
#    1174         else:
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# The above exception was the direct cause of the following exception:
#
# AutoReconnect                             Traceback (most recent call last)
# /var/folders/lc/bd2hdpn53fnd_gtfy8gt049h0000gn/T/ipykernel_61389/674207167.py in <module>
#       1 # Add the txn_history as a collection to the database
# ----> 2 crypto_punks_mdb.traders_col.insert_many(traders_list)
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     587         blk = _Bulk(self, ordered, bypass_document_validation)
#     588         blk.ops = [doc for doc in gen()]
# --> 589         blk.execute(write_concern, session=session)
#     590         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     591
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     446                 self.execute_no_results(sock_info, generator)
#     447         else:
# --> 448             return self.execute_command(generator, write_concern, session)
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     342         client = self.collection.database.client
#     343         with client._tmp_session(session) as s:
# --> 344             client._retry_with_session(
#     345                 self.is_retryable, retryable_bulk, s, self)
#     346
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1227         retryable = (retryable and self.options.retry_writes
#    1228                      and session and not session.in_transaction)
# -> 1229         return self._retry_internal(retryable, func, session, bulk)
#    1230
#    1231     def _retry_internal(self, retryable, func, session, bulk):
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1259                             raise last_error
#    1260                         retryable = False
# -> 1261                     return func(session, sock_info, retryable)
#    1262             except ServerSelectionTimeoutError:
#    1263                 if is_retrying():
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/bulk.py in retryable_bulk(session, sock_info, retryable)
#     336
#     337         def retryable_bulk(session, sock_info, retryable):
# --> 338             self._execute_command(
#     339                 generator, write_concern, session, sock_info, op_id,
#     340                 retryable, full_result)
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/bulk.py in _execute_command(self, generator, write_concern, session, sock_info, op_id, retryable, full_result)
#     292                 ops = islice(run.ops, run.idx_offset, None)
#     293                 # Run as many ops as possible in one command.
# --> 294                 result, to_send = bwc.execute(cmd, ops, client)
#     295
#     296                 # Retryable writeConcernErrors halt the execution of this run.
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/message.py in execute(self, cmd, docs, client)
#     735     def execute(self, cmd, docs, client):
#     736         request_id, msg, to_send = self._batch_command(cmd, docs)
# --> 737         result = self.write_command(cmd, request_id, msg, to_send)
#     738         client._process_response(result, self.session)
#     739         return result, to_send
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/message.py in write_command(self, cmd, request_id, msg, docs)
#     818             start = datetime.datetime.now()
#     819         try:
# --> 820             reply = self.sock_info.write_command(request_id, msg)
#     821             if self.publish:
#     822                 duration = (datetime.datetime.now() - start) + duration
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/pool.py in write_command(self, request_id, msg)
#     792           - `msg`: bytes, the command message.
#     793         """
# --> 794         self.send_message(msg, 0)
#     795         reply = self.receive_message(request_id)
#     796         result = reply.command_response()
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/pool.py in send_message(self, message, max_doc_size)
#     750             self.sock.sendall(message)
#     751         except BaseException as error:
# --> 752             self._raise_connection_failure(error)
#     753
#     754     def receive_message(self, request_id):
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/pool.py in _raise_connection_failure(self, error)
#     916         # SSLError from PyOpenSSL inherits directly from Exception.
#     917         if isinstance(error, (IOError, OSError, _SSLError)):
# --> 918             _raise_connection_failure(self.address, error)
#     919         else:
#     920             raise
#
# ~/miniforge3/lib/python3.9/site-packages/pymongo/pool.py in _raise_connection_failure(address, error, msg_prefix)
#     248         raise NetworkTimeout(msg) from error
#     249     else:
# --> 250         raise AutoReconnect(msg) from error
#     251
#     252
#
# AutoReconnect: cluster0-shard-00-02.wddnt.mongodb.net:27017: [Errno 32] Broken pipe

# %%
# Add the traders as a collection to the database 10,000 records at a time

for runs in range(133):
    start_record = runs*1000
    end_record = 1000 + runs*1000
    if end_record >= 132527:
        end_record = 132526
    print("processing record: ",start_record,"  to: ",end_record)

    # Select the batch to be loaded
    list_to_load = traders_list[start_record:end_record]
  
    # upload the batch to the database collection
    crypto_punks_mdb.traders_col.insert_many(list_to_load)

# Report when done
print ("Export completed ----------------------------")
# Out:
# processing record:  0   to:  1000
# processing record:  1000   to:  2000
# processing record:  2000   to:  3000
# processing record:  3000   to:  4000
# processing record:  4000   to:  5000
# processing record:  5000   to:  6000
# processing record:  6000   to:  7000
# processing record:  7000   to:  8000
# processing record:  8000   to:  9000
# processing record:  9000   to:  10000
# processing record:  10000   to:  11000
# processing record:  11000   to:  12000
# processing record:  12000   to:  13000
# processing record:  13000   to:  14000
# processing record:  14000   to:  15000
# processing record:  15000   to:  16000
# processing record:  16000   to:  17000
# processing record:  17000   to:  18000
# processing record:  18000   to:  19000
# processing record:  19000   to:  20000
# processing record:  20000   to:  21000
# processing record:  21000   to:  22000
# processing record:  22000   to:  23000
# processing record:  23000   to:  24000
# processing record:  24000   to:  25000
# processing record:  25000   to:  26000
# processing record:  26000   to:  27000
# processing record:  27000   to:  28000
# processing record:  28000   to:  29000
# processing record:  29000   to:  30000
# processing record:  30000   to:  31000
# processing record:  31000   to:  32000
# processing record:  32000   to:  33000
# processing record:  33000   to:  34000
# processing record:  34000   to:  35000
# processing record:  35000   to:  36000
# processing record:  36000   to:  37000
# processing record:  37000   to:  38000
# processing record:  38000   to:  39000
# processing record:  39000   to:  40000
# processing record:  40000   to:  41000
# processing record:  41000   to:  42000
# processing record:  42000   to:  43000
# processing record:  43000   to:  44000
# processing record:  44000   to:  45000
# processing record:  45000   to:  46000
# processing record:  46000   to:  47000
# processing record:  47000   to:  48000
# processing record:  48000   to:  49000
# processing record:  49000   to:  50000
# processing record:  50000   to:  51000
# processing record:  51000   to:  52000
# processing record:  52000   to:  53000
# processing record:  53000   to:  54000
# processing record:  54000   to:  55000
# processing record:  55000   to:  56000
# processing record:  56000   to:  57000
# processing record:  57000   to:  58000
# processing record:  58000   to:  59000
# processing record:  59000   to:  60000
# processing record:  60000   to:  61000
# processing record:  61000   to:  62000
# processing record:  62000   to:  63000
# processing record:  63000   to:  64000
# processing record:  64000   to:  65000
# processing record:  65000   to:  66000
# processing record:  66000   to:  67000
# processing record:  67000   to:  68000
# processing record:  68000   to:  69000
# processing record:  69000   to:  70000
# processing record:  70000   to:  71000
# processing record:  71000   to:  72000
# processing record:  72000   to:  73000
# processing record:  73000   to:  74000
# processing record:  74000   to:  75000
# processing record:  75000   to:  76000
# processing record:  76000   to:  77000
# processing record:  77000   to:  78000
# processing record:  78000   to:  79000
# processing record:  79000   to:  80000
# processing record:  80000   to:  81000
# processing record:  81000   to:  82000
# processing record:  82000   to:  83000
# processing record:  83000   to:  84000
# processing record:  84000   to:  85000
# processing record:  85000   to:  86000
# processing record:  86000   to:  87000
# processing record:  87000   to:  88000
# processing record:  88000   to:  89000
# processing record:  89000   to:  90000
# processing record:  90000   to:  91000
# processing record:  91000   to:  92000
# processing record:  92000   to:  93000
# processing record:  93000   to:  94000
# processing record:  94000   to:  95000
# processing record:  95000   to:  96000
# processing record:  96000   to:  97000
# processing record:  97000   to:  98000
# processing record:  98000   to:  99000
# processing record:  99000   to:  100000
# processing record:  100000   to:  101000
# processing record:  101000   to:  102000
# processing record:  102000   to:  103000
# processing record:  103000   to:  104000
# processing record:  104000   to:  105000
# processing record:  105000   to:  106000
# processing record:  106000   to:  107000
# processing record:  107000   to:  108000
# processing record:  108000   to:  109000
# processing record:  109000   to:  110000
# processing record:  110000   to:  111000
# processing record:  111000   to:  112000
# processing record:  112000   to:  113000
# processing record:  113000   to:  114000
# processing record:  114000   to:  115000
# processing record:  115000   to:  116000
# processing record:  116000   to:  117000
# processing record:  117000   to:  118000
# processing record:  118000   to:  119000
# processing record:  119000   to:  120000
# processing record:  120000   to:  121000
# processing record:  121000   to:  122000
# processing record:  122000   to:  123000
# processing record:  123000   to:  124000
# processing record:  124000   to:  125000
# processing record:  125000   to:  126000
# processing record:  126000   to:  127000
# processing record:  127000   to:  128000
# processing record:  128000   to:  129000
# processing record:  129000   to:  130000
# processing record:  130000   to:  131000
# processing record:  131000   to:  132000
# processing record:  132000   to:  132526
# Export completed ----------------------------

# %% [markdown]
# # END
